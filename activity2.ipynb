# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Open Original Image

# %%
image = cv2.imread("profile.jpg")
print("Size of Image: " + str(image.size))
window_name = "Original Image"
# Out:
# Size of Image: 1498176

# %% [markdown]
# # Display Image

# %%
# cv2.imshow(window_name, image)
plt.imshow(image)
cv2.imwrite("act2_orig.png",image)
# Out:
# True
